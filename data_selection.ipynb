# %%
import pandas as pd
import sqlalchemy




DataBase = pd.read_sql_table(
    "time_series_60min_singleindex", "sqlite:///time_series_energy_60min.sqlite3", index_col=0
)

print(DataBase)


DE_wind_profile = DataBase.loc[:, 'DE_wind_profile']
# Out:
#               utc_timestamp        cet_cest_timestamp  \
# 0      2014-12-31T23:00:00Z  2015-01-01T00:00:00+0100
# 1      2015-01-01T00:00:00Z  2015-01-01T01:00:00+0100
# 2      2015-01-01T01:00:00Z  2015-01-01T02:00:00+0100
# 3      2015-01-01T02:00:00Z  2015-01-01T03:00:00+0100
# 4      2015-01-01T03:00:00Z  2015-01-01T04:00:00+0100
# ...                     ...                       ...
# 50396  2020-09-30T19:00:00Z  2020-09-30T21:00:00+0200
# 50397  2020-09-30T20:00:00Z  2020-09-30T22:00:00+0200
# 50398  2020-09-30T21:00:00Z  2020-09-30T23:00:00+0200
# 50399  2020-09-30T22:00:00Z  2020-10-01T00:00:00+0200
# 50400  2020-09-30T23:00:00Z  2020-10-01T01:00:00+0200
#
#        AT_load_actual_entsoe_transparency  \
# 0                                     NaN
# 1                                  5946.0
# 2                                  5726.0
# 3                                  5347.0
# 4                                  5249.0
# ...                                   ...
# ...

# %%
DE_wind_profile = DataBase.loc[:, 'DE_wind_profile']






print(DE_wind_profile)
# Out:
# 0           NaN
# 1        0.3171
# 2        0.3244
# 3        0.3249
# 4        0.3283
#           ...
# 50396       NaN
# 50397       NaN
# 50398       NaN
# 50399       NaN
# 50400       NaN
# Name: DE_wind_profile, Length: 50401, dtype: float64

# %%
DataBase['utc_timestamp'] = pd.to_datetime(DataBase['utc_timestamp'], format='%Y-%m-%dT%H:%M:%SZ', utc=True)
DataBase.set_index('utc_timestamp', inplace=True)



DataBase_without_NA = DataBase.interpolate(method='time')

# %%
#print(DataBase_without_NA)
DE_wind_profile = DataBase_without_NA.loc[:, 'DE_wind_profile']
print(DE_wind_profile[5])
# Out:
# 0.3307
